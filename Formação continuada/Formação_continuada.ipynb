# %% [markdown]
# # Gestão da Qualidade
#
# ## Palestra - Formação continuada
#
# por **Cibele Russo**
#
# **ICMC/USP - São Carlos SP**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import f

# %%
import pandas as pd
url='https://raw.githubusercontent.com/cibelerusso/Gestao-da-qualidade/main/Forma%C3%A7%C3%A3o%20continuada/Educacao.csv'
data = pd.read_csv(url, sep=",", decimal=',') # use sep="," for coma separation. 
data.describe()
# Out:
#        n_amostra         P1         P2  ...         P4      Média  Amplitude
# count  60.000000  60.000000  60.000000  ...  60.000000  60.000000  60.000000
# mean   30.500000   8.016667   7.933333  ...   7.700000   7.688333   5.833333
# std    17.464249   3.265078   3.024570  ...   3.729407   2.229471   2.894569
# min     1.000000   2.000000   3.000000  ...   1.000000   3.000000   1.000000
# 25%    15.750000   6.000000   6.000000  ...   5.000000   6.000000   4.000000
# 50%    30.500000   8.000000   7.500000  ...   7.000000   7.800000   6.000000
# 75%    45.250000  10.000000   9.000000  ...  10.000000   9.300000   7.000000
# max    60.000000  19.000000  19.000000  ...  16.000000  13.800000  15.000000
#
# [8 rows x 7 columns]

# %%
plt.rcParams['figure.figsize'] = [12,6]

# %%
import seaborn as sns

sns.boxplot(x = data['Média'], palette = 'pastel');

# %%
sns.histplot(data['Média'], bins=20, kde=True);

# %% [markdown]
# Separando primeiros 30 alunos e últimos 30 alunos

# %%
data1 = data.iloc[0:30,]
data1.head()
# Out:
#    n_amostra  P1  P2  P3  P4  Média  Amplitude Depois
# 0          1  16   9   6   6    9.3       10.0      0
# 1          2   9   5  14   3    7.8       11.0      0
# 2          3   7   7   7  10    7.8        3.0      0
# 3          4  10  13   7  11   10.3        6.0      0
# 4          5   6   9   4   6    6.3        5.0      0

# %%
data2 = data.iloc[31:60,]
data2.head()
# Out:
#     n_amostra  P1  P2  P3  P4  Média  Amplitude Depois
# 31         32   6   7   8   2    5.8        6.0      1
# 32         33   5   5   4   2    4.0        3.0      1
# 33         34  15   8   5   3    7.8       12.0      1
# 34         35   4   3   2   3    3.0        2.0      1
# 35         36   8   7   5   6    6.5        3.0      1

# %%
data1.describe()
# Out:
#        n_amostra         P1         P2  ...         P4      Média  Amplitude
# count  30.000000  30.000000  30.000000  ...  30.000000  30.000000  30.000000
# mean   15.500000   9.266667   9.500000  ...  10.033333   9.386667   6.500000
# std     8.803408   3.236999   2.979817  ...   3.232201   1.586524   3.181303
# min     1.000000   4.000000   4.000000  ...   3.000000   6.300000   2.000000
# 25%     8.250000   7.000000   8.000000  ...   8.000000   8.575000   4.000000
# 50%    15.500000   9.000000   9.000000  ...  10.000000   9.300000   6.000000
# 75%    22.750000  11.000000  11.000000  ...  12.000000  10.225000   8.000000
# max    30.000000  19.000000  19.000000  ...  16.000000  13.800000  15.000000
#
# [8 rows x 7 columns]

# %%
data2.describe()
# Out:
#        n_amostra         P1         P2  ...         P4      Média  Amplitude
# count  29.000000  29.000000  29.000000  ...  29.000000  29.000000   29.00000
# mean   46.000000   6.896552   6.137931  ...   5.241379   5.927586    5.00000
# std     8.514693   2.781891   1.787339  ...   2.516448   1.250970    2.31455
# min    32.000000   2.000000   3.000000  ...   1.000000   3.000000    1.00000
# 25%    39.000000   5.000000   5.000000  ...   3.000000   5.500000    3.00000
# 50%    46.000000   7.000000   6.000000  ...   5.000000   6.000000    5.00000
# 75%    53.000000   8.000000   7.000000  ...   7.000000   6.800000    6.00000
# max    60.000000  15.000000  10.000000  ...  10.000000   8.800000   12.00000
#
# [8 rows x 7 columns]

# %%
data['Depois'] = 0
data['Depois'].iloc[31:60] = 1 
data.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     n_amostra  P1  P2  P3  P4  Média  Amplitude  Depois
# 55         56   8   9   3  10    7.5        7.0       1
# 56         57   4   4   9   2    4.8        7.0       1
# 57         58  10   6   4   7    6.8        6.0       1
# 58         59   6   7   2   9    6.0        7.0       1
# 59         60   2   7   3   3    3.8        5.0       1

# %%
sns.boxplot(y = data['Média'], x = data['Depois'], palette = 'pastel')

# %%
sns.histplot(x = data['Média'], hue = data['Depois'], bins=20, kde=True, palette = 'pastel')

# %%
# !pip install GaugeRnR
# Out:
# Collecting GaugeRnR
#   Downloading GaugeRnR-0.6.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from GaugeRnR) (4.4.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from GaugeRnR) (0.10.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from GaugeRnR) (0.8.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from GaugeRnR) (1.19.5)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from GaugeRnR) (0.6.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from GaugeRnR) (1.4.1)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->GaugeRnR) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly->GaugeRnR) (1.15.0)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from statsmodels->GaugeRnR) (1.1.5)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->GaugeRnR) (0.5.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->GaugeRnR) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->GaugeRnR) (2018.9)
# Installing collected packages: GaugeRnR
# Successfully installed GaugeRnR-0.6.0

# %%
import numpy as np
import GaugeRnR
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import seaborn as sns
import pandas as pd
plt.style.use('seaborn-colorblind')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
# Apenas execute essa célula
# Fonte: https://www.kaggle.com/nalkrolu/statistical-process-control-quality-control/notebook#X-R-Control-Chart

class XR_ControlChart:
    
    def fit(self,data):
        
        self.sample_size = len(data[0])
        self.number_of_sample = len(data)
        self.X = np.zeros((self.number_of_sample,1))
        self.R = np.zeros((self.number_of_sample,1))

        for i in range(self.number_of_sample):
            self.X[i] = data[i].mean()
            self.R[i] = data[i].max() - data[i].min()
        
        self.data = data
        
    def ControlChart(self,A2,D3,D4):

        ucl_X   = self.X.mean() + A2*self.R.mean()
        cl_X    = self.X.mean() 
        lcl_X   = self.X.mean() - A2*self.R.mean()

        ucl_R   = D4*self.R.mean()
        cl_R    = self.R.mean() 
        lcl_R   = D3*self.R.mean()
        
        plt.figure(figsize=(15,5))
        plt.title("Boxplot for {} Observations\nSample Size {}".format(len(self.data),len(self.data[0])))
        plt.boxplot(self.data.T)
        plt.show()

        plt.figure(figsize=(15,5))
        plt.plot(self.X,marker="o",color="k",label="X")
        plt.plot([ucl_X]*len(self.X),color="r",label="UCL={}".format(ucl_X.round(2)))
        plt.plot([cl_X]*len(self.X),color="b",label="CL={}".format(cl_X.round(2)))
        plt.plot([lcl_X]*len(self.X),color="r",label="LCL={}".format(lcl_X.round(2)))
        plt.title("X Chart")
        plt.xticks(np.arange(len(self.data)))
        plt.legend()
        plt.show()

        plt.figure(figsize=(15,5))
        plt.plot(self.R,marker="o",color="k",label="R")
        plt.plot([ucl_R]*len(self.X),color="r",label="UCL={}".format(ucl_R.round(2)))
        plt.plot([cl_R]*len(self.X),color="b",label="CL={}".format(cl_R.round(2)))
        plt.plot([lcl_R]*len(self.X),color="r",label="LCL={}".format(lcl_R.round(2)))
        plt.title("R Chart")
        plt.xticks(np.arange(len(self.data)))
        plt.legend()
        plt.show()
        
        plt.figure(figsize=(15,5))
        plt.subplot(1,2,1)
        plt.boxplot(x=self.X)
        plt.title("Boxplot X")
        plt.xlabel("X")
        plt.subplot(1,2,2)
        plt.boxplot(x=self.R)
        plt.title("Boxplot R")
        plt.xlabel("R")
        plt.show()

# %%
data_controle = np.array(data[['P1','P2','P3','P4']])

# %%
chart = XR_ControlChart()
chart.fit(data_controle)
chart.ControlChart(A2 = 0.729,D3 = 0 ,D4 = 2.282)

# %%
data1_controle = np.array(data1[['P1','P2','P3','P4']])
chart = XR_ControlChart()
chart.fit(data1_controle)
chart.ControlChart(A2 = 0.729,D3 = 0 ,D4 = 2.282)

# %%
data2_controle = np.array(data2[['P1','P2','P3','P4']])
chart = XR_ControlChart()
chart.fit(data2_controle)
chart.ControlChart(A2 = 0.729,D3 = 0 ,D4 = 2.282)

# %%
from scipy import stats

stats.ttest_ind(data1['Média'],data2['Média'])


stats.ttest_ind(data1['Média'],data2['Média'], equal_var=False)
# Out:
# Ttest_indResult(statistic=9.316093371146462, pvalue=6.844397713125599e-13)
